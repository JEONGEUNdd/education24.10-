# %%
#네이버메일 보내기
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
import pyautogui
import pyperclip

def main():
    uid=pyautogui.prompt("네이버ID: ")
    pwd=pyautogui.password("비밀번호: ")
    toname=pyautogui.prompt("받는사람 이름: ", default="홍길동")
    tomail=pyautogui.prompt("받는사람 메일: ", default="s3458600@gmail.com")
    response=pyautogui.confirm(
        "어떤 내용을 하시겠습니까?",
        buttons=['가입안내','합격안내','계약서']
    )
    if response=="가입안내":
        to_subject="[테스트] 가입안내입니다."
        to_content=f"{toname}님 가입을 환영합니다 \n\n최고의 서비스로 최선을 다하겠습니다."
    elif response=="합격안내":
        to_subject="[테스트] 합격결과입니다."
        to_content=f'''{toname}님 이번 면접에 최종 합격하였습니다.\n
    저희 가족이 되심을 축하합니다.
    입사일은 2025년 1월 1일입니다.\n
    감사합니다'''
    elif response=="계약서":
        to_subject="[테스트] 점심 계약서"
        to_content=f'''{toname}님 최종 계약서 내용입니다."\n
귀하는 2024년 12월 4일 점심을 사기로 했습니다.
#계약자 A:{toname}
#계약자 B:이순신'''
    if not uid or not pwd or not tomail:
        pyautogui.alert("ID 또는 비밀번호가 비어있습니다. 프로그램을 종료합니다.")
        return

    # 브라우저 꺼짐 방지
    chrome_options = Options()
    chrome_options.add_experimental_option("detach", True)
    
    # 불필요한 에러메시지 노출 방지
    chrome_options.add_experimental_option("excludeSwitches", ["enable-logging"])
    
    driver = webdriver.Chrome(options = chrome_options)
    
    driver.implicitly_wait(5) # 웹페이지 로딩 될때까지 5초 wait
    driver.maximize_window()  # 화면 최대화
    
    # 이동하려는 해당 웹페이지 주소
    driver.get("https://nid.naver.com/nidlogin.login?mode=form&url=https://www.naver.com/")
    time.sleep(1)
    
    # 아이디 입력창
    id = driver.find_element(By.CSS_SELECTOR, "#input_item_id")
    # 클릭 하도록 설정
    id.click()
    # 키보드 입력 설정
    #id.send_keys("네이버 아이디") # "네이버 아이디"에는 본인 네이버 아이디 입력
    pyperclip.copy(uid)
    pyautogui.hotkey("ctrl", "v")
    
    time.sleep(2)
    
    # 비밀번호 입력창 찾기
    pw = driver.find_element(By.CSS_SELECTOR, "#input_item_pw")
    # 클릭하도록 설정
    pw.click()
    # 키보드 입력 설정
    #pw.send_keys("네이버 비밀번호") # "네이버 비밀번호"에는 본인 네이버 비밀번호 입력
    pyperclip.copy(pwd)
    pyautogui.hotkey("ctrl", "v")
    time.sleep(2)
    
    # 로그인 버튼 클릭
    login_btn = driver.find_element(By.CSS_SELECTOR, "#log\\.login")
    login_btn.click()
    # 메일 버튼 클릭
    mail_btn = driver.find_element(By.CSS_SELECTOR, "#shortcutArea > ul > li:nth-child(1) > a > span.service_icon.type_mail")
    mail_btn.click()
    time.sleep(2)
    
    # 신규탭으로 전환
    windows = driver.window_handles
    driver.switch_to.window(windows[-1])
    
    time.sleep(2)
    
    # 메일 쓰기
    write_btn = driver.find_element(By.CSS_SELECTOR, "#root > div > nav > div > div.lnb_header > div.lnb_task > a.item.button_write")
    write_btn.click()
    
    # 받는 메일주소
    to_email = driver.find_element(By.CSS_SELECTOR, "#recipient_input_element")
    to_email.click()
    pyperclip.copy("s3458600@gmail.com")
    pyautogui.hotkey("ctrl", "v")
    time.sleep(2)
    
    # 메일 제목
    subject_email = driver.find_element(By.CSS_SELECTOR, "#subject_title")
    subject_email.click()
    pyperclip.copy("테스트 메일 보내기입니다.")
    pyautogui.hotkey("ctrl", "v")
    
    time.sleep(2)
    
    # iframe 창으로 전환
    iframe = driver.find_element(By.CSS_SELECTOR,"#content > div.contents_area > div > div.editor_area > div > div.editor_body > iframe")
    driver.switch_to.frame(iframe)
    
    time.sleep(2)
    
    # 메일 내용
    mail_content = driver.find_element(By.CSS_SELECTOR, "body > div > div.workseditor-content")
    mail_content.click()
    pyperclip.copy(to_content)
    pyautogui.hotkey("ctrl","v")
    
    # 본 창으로 전환
    driver.switch_to.default_content()
    
    #보내기 버튼
    mail_content = driver.find_element(By.CSS_SELECTOR, "#content > div.mail_toolbar.type_write > div:nth-child(1) > div > button.button_write_task")
    mail_content.click()
main()

# %% [raw]
# 변수명=Select(driver.find_element(By.ID,"country"))
#
# 변수명.select_by_visible_text("한국")  #보여지는 텍스트 기준
# 변수명.select_by_value("korea")  #value값 기준
# 변수명.select_by_index(0)  #인덱스 기준 선택
#
# [multiple 조건에서]
# 변수명.deselect_by_visible_text("한국") #보여지는 텍스트 기준 해제
# 변수명.deselect_by_value("korea")  #value값 기준 해제
# 변수명.deselect_by_index(0)  #인덱스 기준 선택 해제

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import time
import pyautogui
import pyperclip

driver = webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=register")

driver.find_element(By.ID, "name").send_keys("홍길동")
driver.find_element(By.ID, "email").send_keys("gildong123@gmail.com")

con=Select(driver.find_element(By.ID,"country"))
con.select_by_visible_text("한국")  #보여지는 텍스트기준

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import pyautogui
import pyperclip

driver = webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=survey")

#선택2클릭
s2=driver.find_element(By.CSS_SELECTOR,"input[value='option1']")
s2.click()

#관심사항1 클릭
interest=driver.find_element(By.NAME,"interests")
interest.click()

#의견입력
textarea=driver.find_element(By.ID,"comments")
textarea.send_keys("의견 넣을 내용")

###################################################################################################
#선택2 클릭
# s2=driver.find_element(By.CSS_SELECTOR, "#survey-form > div:nth-child(1) > div > label:nth-child(2)")
# s2.click()

# #관심사항1 클릭
# interest=driver.find_element(By.CSS_SELECTOR, "#survey-form > div:nth-child(2) > div > label:nth-child(1) > input[type=checkbox]")
# interest.click()

#의견 입력
# opinion=driver.find_element(By.CSS_SELECTOR, "#comments")
# opinion.click()
# pyperclip.copy("의견 넣을 내용")
# pyautogui.hotkey("ctrl", "v")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import pyautogui
import pyperclip

driver = webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=order")

#수량값(5) 지우고 다시 입력
quantity=driver.find_element(By.ID,"quantity")
quantity.clear()
quantity.send_keys("7")

#배송주소
address=driver.find_element(By.ID,"address")
address.send_keys("서울시 강남구 어디어디")

#연락처
phonenumber=driver.find_element(By.ID,"phone")
phonenumber.send_keys("010-1234-5678")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

driver = webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=menu")

#About클릭
# ab=driver.find_element(By.CSS_SELECTOR,"body > nav > a:nth-child(2)")
# ab.click()

ab=driver.find_elements(By.CLASS_NAME,"menu-item")
ab[1].click()

# %%
#버튼 선택하기
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import pyautogui
import pyperclip

driver = webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=pagination")

button=driver.find_elements(By.TAG_NAME,"a")[2]
button.click()

# button=driver.find_element(By.CSS_SELECTOR,"body > div > a:nth-child(4)")
# button.click()

# button=driver.find_element(By.LINK_TEXT,"2")
# button.click()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import pyautogui
import pyperclip

driver = webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=tabs")

# tab1=driver.find_element(By.CSS_SELECTOR,"#tab1")
# tab1.click()

tab1=driver.find_element(By.ID,"tab1")
tab1.click()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

chrome_options=webdriver.ChromeOptions()
chrome_options.add_experimental_option("prefs",{
    "download.default_directory": "C:\\Users\\enjoy\\Downloads",  #다운받을 파일 경로 지정
    "download.prompt_for_download":False
})

driver=webdriver.Chrome(options=chrome_options)
driver.get("http://lecture.pul.kr/ex5.html?act=download")

download_btn=driver.find_element(By.ID,"download-btn")
download_btn.click()

time.sleep(5)

# %%
#파일 업로드
driver=webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=upload")

file_input=driver.find_element(By.ID,"file-upload")
file_input.send_keys(r"C:\Users\enjoy\Downloads\Roboto.zip")

upload_btn=driver.find_element(By.ID,"upload-btn")
#upload_btn.click()

# %%
#여러 파일 업로드
driver=webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=multi-upload")

files_input=driver.find_element(By.ID,"multiple-files")
files_input.send_keys("C:\\Users\\enjoy\\Downloads\\tv.png\nC:\\Users\\enjoy\\python_202411\\data.csv")

upload_btn=driver.find_element(By.ID,"multi-upload-btn")
#upload_btn.click()

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.get("https://exmaple.com")

element_to_click=driver.find_element(By.ID,"example_id")
actions.click(element_to_click)

# %%
#ActionChains(드래그앤드랍)
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
import time

driver=webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=dragdrop")

source=driver.find_element(By.ID,'draggable')
target=driver.find_element(By.ID,'droppable')

actions=ActionChains(driver)

actions.drag_and_drop(source,target).perform()

# %% [raw]
# 3. context_click(element)
# 설명: 지정된 요소에서 마우스 오른쪽 버튼을 클릭
#
# 4. move_to_element(element)
# 설명: 지정된 요소 위로 마우스를 이동
#
# 5. move_by_offset(x_offset, y_offset)
# 설명: 현재 마우스 위치에서 특정 오프셋만큼 이동
#
# 6. drag_and_drop(source, target)
# 설명: 소스 요소를 타겟 요소로 드래그 앤 드롭
#
# 7. send_keys(*keys)
# 설명: 지정한 키를 입력합니다. 여러 키를 동시에 입력
#
# 8. click_and_hold(source)
# 소스 요소를 클릭하고 그 상태를 유지. 이 상태에서 마우스를 이동
#
# 9. release()
# 클릭한 상태를 해제하여 드래그한 요소를 타겟에 놓음
#
# 10. pause(2)
# 다음 동작을 수행하기 전에 2초 동안 대기. 대기 시간을 설정하여 사용자가 동작을 시각적으로 확인
#
# 11. perform()
# 설명: 지금까지 설정한 모든 작업을 실행
#
# 12. reset_actions()
# 설명: 현재 ActionChains 객체의 작업을 초기화
#
# 13. key_down(value, element=None)
# 설명: 특정 키를 눌러서 상태를 유지. 선택적으로 요소를 지정
#
# 14. key_up(value, element=None)
# 설명: 특정 키를 눌렀던 상태를 해제. 선택적으로 요소를 지정

# %%
#ActionChains(정렬)
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=sortable")

item1=driver.find_element(By.ID,"item1")
item2=driver.find_element(By.ID,"item2")

#인스턴스 생성
actions=ActionChains(driver)

actions.click_and_hold(item1)\
    .move_to_element(item2)\
    .move_by_offset(0,5)\
    .pause(0.5)\ 
    .release()\
    .perform()

# %%
#이미지 드래그
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By

driver=webdriver.Chrome()
driver.get("http://lecture.pul.kr/ex5.html?act=gallery")

source=driver.find_elements(By.CLASS_NAME,'gallery-item')[0]
target=driver.find_element(By.CLASS_NAME,'drop-zone')

#인스턴스 생성
actions=ActionChains(driver)

actions.drag_and_drop(source,target).perform()
